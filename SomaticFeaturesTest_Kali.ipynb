# %%
#pip install sciunit quantities efel scipy json2html neurom

# %%
#% matplotlib notebook
% matplotlib inline
from json2html import *
from quantities import mV, nA
import IPython
import json
import collections

#import sciunit
from hippounit import models
from hippounit import tests
#from hippounit import capabilities

#import matplotlib.pyplot as plt


from neuron import h

# %%
# Load target data

with open('./stimfeat/PC_newfeat_No14112401_15012303-m990803_stimfeat.json') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
observation = config['features']
IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>AP1_amp.Step1.0</th><td><table border="1"><tr><th>Std</th><td>5.46582296368</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>84.8916666031</td></tr><tr><th>Stimulus</th><td>Step1.0</td></tr><tr><th>Type</th><td>AP1_amp</td></tr></table></td></tr><tr><th>APlast_amp.Step1.0</th><td><table border="1"><tr><th>Std</th><td>12.94176933</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>61.2768380869</td></tr><tr><th>Stimulus</th><td>Step1.0</td></tr><tr><th>Type</th><td>APlast_amp</td></tr></table></td></tr><tr><th>AHP_depth.Step1.0</th><td><table border="1"><tr><th>Std</th><td>4.91970618493</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>12.1357640551</td></tr><tr><th>Stimulus</th><td>Step1.0</td></tr><tr><th>Type</th><td>AHP_depth</td></tr></table></td></tr><tr><th>voltage_deflection.Step-2.0</th><td><table border="1"><tr><th>Std</th><td>14.4013027106</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>-45.0851328288</td></tr><tr><th>Stimulus</th><td>Step-2.0</td></tr><tr><th>Type</th><td>voltage_deflection</td></tr></table></td></tr><tr><th>voltage_deflection.Step-1.0</th><td><table border="1"><tr><th>Std</th><td>5.97743835886</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>-22.9514081558</td></tr><tr><th>Stimulus</th><td>Step-1.0</td></tr><tr><th>Type</th><td>voltage_deflection</td></tr></table></td></tr><tr><th>voltage_deflection_begin.Step-2.0</th><td><table border="1"><tr><th>Std</th><td>15.7193976351</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>-50.2771542801</td></tr><tr><th>Stimulus</th><td>Step-2.0</td></tr><tr><th>Type</th><td>voltage_deflection_begin</td></tr></table></td></tr><tr><th>voltage_deflection_begin.Step-1.0</th><td><table border="1"><tr><th>Std</th><td>7.60658440662</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>-26.9601994129</td></tr><tr><th>Stimulus</th><td>Step-1.0</td></tr><tr><th>Type</th><td>voltage_deflection_begin</td></tr></table></td></tr><tr><th>time_to_last_spike.Step0.2</th><td><table border="1"><tr><th>Std</th><td>123.499701459</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>83.4799264706</td></tr><tr><th>Stimulus</th><td>Step0.2</td></tr><tr><th>Type</th><td>time_to_last_spike</td></tr></table></td></tr><tr><th>time_to_last_spike.Step0.4</th><td><table border="1"><tr><th>Std</th><td>141.569702022</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>187.077745098</td></tr><tr><th>Stimulus</th><td>Step0.4</td></tr><tr><th>Type</th><td>time_to_last_spike</td></tr></table></td></tr><tr><th>time_to_last_spike.Step0.6</th><td><table border="1"><tr><th>Std</th><td>121.350947588</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>267.77495098</td></tr><tr><th>Stimulus</th><td>Step0.6</td></tr><tr><th>Type</th><td>time_to_last_spike</td></tr></table></td></tr><tr><th>time_to_last_spike.Step0.8</th><td><table border="1"><tr><th>Std</th><td>112.16782043</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>279.147794118</td></tr><tr><th>Stimulus</th><td>Step0.8</td></tr><tr><th>Type</th><td>time_to_last_spike</td></tr></table></td></tr><tr><th>time_to_last_spike.Step1.0</th><td><table border="1"><tr><th>Std</th><td>113.050566913</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>296.700294118</td></tr><tr><th>Stimulus</th><td>Step1.0</td></tr><tr><th>Type</th><td>time_to_last_spike</td></tr></table></td></tr><tr><th>inv_time_to_first_spike.Step0.2</th><td><table border="1"><tr><th>Std</th><td>33.1818009502</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>22.920294291</td></tr><tr><th>Stimulus</th><td>Step0.2</td></tr><tr><th>Type</th><td>inv_time_to_first_spike</td></tr></table></td></tr><tr><th>inv_time_to_first_spike.Step0.4</th><td><table border="1"><tr><th>Std</th><td>66.7987755836</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Mean</th><td>58.2856477082</td></tr><tr><th>Stimulus</th><td>St ...

# %%
#stimuli
IPython.display.HTML(json2html.convert(json = config['stimuli']))
# Out:
# <table border="1"><tr><th>Step-2.0</th><td><table border="1"><tr><th>Delay</th><td>1000</td></tr><tr><th>RecLocationX</th><td>0.5</td></tr><tr><th>TTX</th><td>0.0</td></tr><tr><th>StimLocationX</th><td>0.5</td></tr><tr><th>Threshold</th><td>-20.0</td></tr><tr><th>Amplitude</th><td>-2.0</td></tr><tr><th>Duration</th><td>400.0</td></tr><tr><th>HypAmp</th><td>0.0</td></tr><tr><th>Type</th><td>SquarePulse</td></tr><tr><th>StimSectionName</th><td>soma[0]</td></tr><tr><th>RecSectionName</th><td>soma[0]</td></tr></table></td></tr><tr><th>Step-1.0</th><td><table border="1"><tr><th>Delay</th><td>1000</td></tr><tr><th>RecLocationX</th><td>0.5</td></tr><tr><th>TTX</th><td>0.0</td></tr><tr><th>StimLocationX</th><td>0.5</td></tr><tr><th>Threshold</th><td>-20.0</td></tr><tr><th>Amplitude</th><td>-1.0</td></tr><tr><th>Duration</th><td>400.0</td></tr><tr><th>HypAmp</th><td>0.0</td></tr><tr><th>Type</th><td>SquarePulse</td></tr><tr><th>StimSectionName</th><td>soma[0]</td></tr><tr><th>RecSectionName</th><td>soma[0]</td></tr></table></td></tr><tr><th>Step0.2</th><td><table border="1"><tr><th>Delay</th><td>1000</td></tr><tr><th>RecLocationX</th><td>0.5</td></tr><tr><th>TTX</th><td>0.0</td></tr><tr><th>StimLocationX</th><td>0.5</td></tr><tr><th>Threshold</th><td>-20.0</td></tr><tr><th>Amplitude</th><td>0.2</td></tr><tr><th>Duration</th><td>400.0</td></tr><tr><th>HypAmp</th><td>0.0</td></tr><tr><th>Type</th><td>SquarePulse</td></tr><tr><th>StimSectionName</th><td>soma[0]</td></tr><tr><th>RecSectionName</th><td>soma[0]</td></tr></table></td></tr><tr><th>Step0.4</th><td><table border="1"><tr><th>Delay</th><td>1000</td></tr><tr><th>RecLocationX</th><td>0.5</td></tr><tr><th>TTX</th><td>0.0</td></tr><tr><th>StimLocationX</th><td>0.5</td></tr><tr><th>Threshold</th><td>-20.0</td></tr><tr><th>Amplitude</th><td>0.4</td></tr><tr><th>Duration</th><td>400.0</td></tr><tr><th>HypAmp</th><td>0.0</td></tr><tr><th>Type</th><td>SquarePulse</td></tr><tr><th>StimSectionName</th><td>soma[0]</td></tr><tr><th>RecSectionName</th><td>soma[0]</td></tr></table></td></tr><tr><th>Step0.6</th><td><table border="1"><tr><th>Delay</th><td>1000</td></tr><tr><th>RecLocationX</th><td>0.5</td></tr><tr><th>TTX</th><td>0.0</td></tr><tr><th>StimLocationX</th><td>0.5</td></tr><tr><th>Threshold</th><td>-20.0</td></tr><tr><th>Amplitude</th><td>0.6</td></tr><tr><th>Duration</th><td>400.0</td></tr><tr><th>HypAmp</th><td>0.0</td></tr><tr><th>Type</th><td>SquarePulse</td></tr><tr><th>StimSectionName</th><td>soma[0]</td></tr><tr><th>RecSectionName</th><td>soma[0]</td></tr></table></td></tr><tr><th>Step0.8</th><td><table border="1"><tr><th>Delay</th><td>1000</td></tr><tr><th>RecLocationX</th><td>0.5</td></tr><tr><th>TTX</th><td>0.0</td></tr><tr><th>StimLocationX</th><td>0.5</td></tr><tr><th>Threshold</th><td>-20.0</td></tr><tr><th>Amplitude</th><td>0.8</td></tr><tr><th>Duration</th><td>400.0</td></tr><tr><th>HypAmp</th><td>0.0</td></tr><tr><th>Type</th><td>SquarePulse</td></tr><tr><th>StimSectionName</th><td>soma[0]</td></tr><tr><th>RecSectionName</th><td>soma[0]</td></tr></table></td></tr><tr><th>Step1.0</th><td><table border="1"><tr><th>Delay</th><td>1000</td></tr><tr><th>RecLocationX</th><td>0.5</td></tr><tr><th>TTX</th><td>0.0</td></tr><tr><th>StimLocationX</th><td>0.5</td></tr><tr><th>Threshold</th><td>-20.0</td></tr><tr><th>Amplitude</th><td>1.0</td></tr><tr><th>Duration</th><td>400.0</td></tr><tr><th>HypAmp</th><td>0.0</td></tr><tr><th>Type</th><td>SquarePulse</td></tr><tr><th>StimSectionName</th><td>soma[0]</td></tr><tr><th>RecSectionName</th><td>soma[0]</td></tr></table></td></tr></table>

# %%
#Load and visualize cell model

model = models.Model()

# outputs will be saved in folders named like this:
model.name="Kali_depol_block_proba"

# path to mod files
model.modelpath = "./hippounit/models/hoc_models/Kali_Freund_modell/scppinput/"

# if this doesn't exist mod files are automatically compiled
model.libpath = "x86_64/.libs/libnrnmech.so.0"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "./hippounit/models/hoc_models/Kali_Freund_modell/scppinput/ca1_syn_NaBG_KDRS4_params_voltage_dep_AXON_Bianchi_KM2_params_SOMA2.hoc"

# If the hoc file doesn't contain a template, this must be None
model.template_name = None

# should be None, if there is no Section List in the model for the soma
model.SomaSecList_name = None

# if the soma is not in a section list, add its name here:
model.soma = 'soma'

model.load_mod_files() #This automatically compiles mod files, if they are not yet compiled
model.initialise() # Loads the model, creates stand alone cell from template. 
# uses the soma section list to set the location of somatic stimuli (and measurement)
# If the given section list contains more elements, the last one is used


# use this to visualize hoc morphology
from PyNeuronToolbox.morphology import shapeplot
from mpl_toolkits.mplot3d import Axes3D
plt.figure(figsize=(7,7))
shapeax = plt.subplot(111, projection='3d')
shapeax.view_init(75,66)
shapeplot(h,shapeax)
plt.show()


'''
from neurom import load_neuron
from neurom import viewer
morph_path = "/home/osboxes/bsp_data_repository-master/optimizations/CA1_pyr_cAC_12AUG16/morphology/dend-050921AM2_axon-051208AM2.asc"
viewer.draw(load_neuron(morph_path))
'''
# Out:
# '\nfrom neurom import load_neuron\nfrom neurom import viewer\nmorph_path = "/home/osboxes/bsp_data_repository-master/optimizations/CA1_pyr_cAC_12AUG16/morphology/dend-050921AM2_axon-051208AM2.asc"\nviewer.draw(load_neuron(morph_path))\n'

# %%
#all the outputs will be saved here
base_directory = '/home/osboxes/BBP_project/150904_neuronunit/neuronunit/'


# Set the test
#The vectors of the somatic and dendritic voltage values are saved in files during the simulation. 
#If force_run=False, and the files already exist, the test uses the saved files for further calculations 
#If force_run=True, or the files don't exist, the test runs the whole simulation.
show_plot=True
test = tests.SomaticFeaturesTest(observation, force_run=False, base_directory=base_directory, show_plot=show_plot)


# Set the number of processes running parallel
import multiprocessing
test.npool = multiprocessing.cpu_count() - 1

# set the target data to be used in the test
test.config=config

# %%
# Run the test
# Call SciUnit's judge function. 
#This calls the generate_prediction function of the test to generate prediction (data of model behaviour)
#Also calls the compute_score function of the test to calculate the error
score = test.judge(model)
# Out:
# The figures are saved in the directory:  ./figs/soma/Kali_depol_block_proba/
# Results are saved in the directory:  ./results/Kali_depol_block_proba/

# %%
# Visualize model feature values in a table
for key, value in score.prediction.iteritems():
    for _key_, value in score.prediction[key].iteritems():
        score.prediction[key][_key_] = str(value)
               
IPython.display.HTML(json2html.convert(json = score.prediction))
# Out:
# <table border="1"><tr><th>inv_first_ISI.Step0.4</th><td><table border="1"><tr><th>feature mean</th><td>42.0168067227</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_first_ISI.Step0.6</th><td><table border="1"><tr><th>feature mean</th><td>64.5161290322</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_first_ISI.Step0.2</th><td><table border="1"><tr><th>feature mean</th><td>12.3609394314</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_first_ISI.Step0.8</th><td><table border="1"><tr><th>feature mean</th><td>81.9672131147</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>AP1_amp.Step1.0</th><td><table border="1"><tr><th>feature mean</th><td>110.83778328</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_time_to_first_spike.Step0.8</th><td><table border="1"><tr><th>feature mean</th><td>499.99999996</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_fourth_ISI.Step1.0</th><td><table border="1"><tr><th>feature mean</th><td>71.9424460432</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_time_to_first_spike.Step0.4</th><td><table border="1"><tr><th>feature mean</th><td>222.222222214</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_time_to_first_spike.Step1.0</th><td><table border="1"><tr><th>feature mean</th><td>624.999999938</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_time_to_first_spike.Step0.6</th><td><table border="1"><tr><th>feature mean</th><td>370.370370349</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_time_to_first_spike.Step0.2</th><td><table border="1"><tr><th>feature mean</th><td>90.9090909078</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_fifth_ISI.Step0.6</th><td><table border="1"><tr><th>feature mean</th><td>35.4609929078</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_third_ISI.Step0.8</th><td><table border="1"><tr><th>feature mean</th><td>59.5238095239</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>APlast_amp.Step1.0</th><td><table border="1"><tr><th>feature mean</th><td>72.2873237177</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_third_ISI.Step0.4</th><td><table border="1"><tr><th>feature mean</th><td>19.2307692308</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_third_ISI.Step1.0</th><td><table border="1"><tr><th>feature mean</th><td>73.5294117648</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>inv_third_ISI.Step0.6</th><td><table border="1"><tr><th>feature mean</th><td>41.1522633745</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>AHP_depth.Step1.0</th><td><table border="1"><tr><th>feature mean</th><td>4.44340837087</td></tr><tr><th>feature sd</th><td>1.20812828606</td></tr></table></td></tr><tr><th>inv_third_ISI.Step0.2</th><td><table border="1"><tr><th>feature mean</th><td>7.87401574804</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>time_to_last_spike.Step0.6</th><td><table border="1"><tr><th>feature mean</th><td>373.4</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>time_to_last_spike.Step0.4</th><td><table border="1"><tr><th>feature mean</th><td>356.4</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>voltage_deflection_begin.Step-2.0</th><td><table border="1"><tr><th>feature mean</th><td>-130.784061725</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>time_to_last_spike.Step0.2</th><td><table border="1"><tr><th>feature mean</th><td>335.7</td></tr><tr><th>feature sd</th><td>0.0</td></tr></table></td></tr><tr><th>time_to_last_spike.Step0.8</th><td><table border="1"><tr><th>feature mean</th><td>399.0</td></tr><tr><th>f ...

# %%
#Summarize and print the score achieved by the model on the test using SciUnit's summarize function
score.summarize()
# Out:
# === Model Kali_depol_block_proba (Model) achieved score Z_sum = 75.67 on test 'Somatic features test (SomaticFeaturesTest)'. ===
